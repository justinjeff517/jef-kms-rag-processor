# %%
import boto3
from botocore.client import Config
from dotenv import load_dotenv
import os
load_dotenv()

spaces_endpoint = os.getenv("SPACES_ENDPOINT")
spaces_access_key = os.getenv("SPACES_ACCESS_KEY")
spaces_secret_key = os.getenv("SPACES_SECRET_KEY")
# DigitalOcean Spaces credentials
access_key = spaces_access_key
secret_key = spaces_secret_key
endpoint_url = spaces_endpoint # Replace with your region's endpoint

# Create a session using your credentials
session = boto3.session.Session()

# Connect to the Spaces service
s3_client = session.client(
    's3',
    endpoint_url=endpoint_url,
    aws_access_key_id=access_key,
    aws_secret_access_key=secret_key,
    config=Config(signature_version='s3v4')
)

# List all buckets to verify the connection
try:
    response = s3_client.list_buckets()
    print("Connection successful! Buckets:")
    for bucket in response['Buckets']:
        print(f"- {bucket['Name']}")
except Exception as e:
    print(f"Error connecting to DigitalOcean Spaces: {e}")
# Out:
# Connection successful! Buckets:
# Error connecting to DigitalOcean Spaces: 'Buckets'

# %%
response = s3_client.list_buckets(
    MaxBuckets=2,
    ContinuationToken='sampletoken',
    Prefix='any',
    BucketRegion='sgp1'
)
#Print the response
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': 'tx0000001d0458999c9b9c1-00679db7b7-44ff8889-sgp1b', 'HostId': '', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-request-id': 'tx0000001d0458999c9b9c1-00679db7b7-44ff8889-sgp1b', 'content-type': 'application/xml', 'date': 'Sat, 01 Feb 2025 05:57:11 GMT', 'strict-transport-security': 'max-age=15552000; includeSubDomains; preload', 'x-envoy-upstream-healthchecked-cluster': '', 'transfer-encoding': 'chunked'}, 'RetryAttempts': 0}, 'Prefix': 'any'}
